# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd

# %%
ROUTES_PATH = 'http://tosamara.ru/api/classifiers/routesAndStopsCorrespondence.xml'

# %%
req = requests.get(ROUTES_PATH)
tree = ET.fromstring(req.text)
tree
# Out:
# <Element 'routes' at 0x0000025417EAF548>

# %%
routes = []
for child in tree:
    number = child[1].text
    direction = child[2].text
    type_id = int(child[3][0].text)
    performing = bool(child[4].text)
    geometry = child[-1].text.split(' ')
    routes.append({'number': number,
                  'direction': direction,
                  'type_id': type_id,
                  'performing' : performing,
                  'geometry' : geometry})

# %%
df_routes = pd.DataFrame.from_records(routes)
df_routes.head()
# Out:
#   number               direction  type_id  performing  \
# 0      1  Железнодорожный вокзал        1        True
# 1      1          Красная Глинка        1        True
# 2     21               Юнгородок        1        True
# 3     21        Барбошина Поляна        1        True
# 4     27         кинотеатр "Луч"        1        True
#
#                                             geometry
# 0  [53.384692,50.169369, 53.384749,50.169603, 53....
# 1  [53.187111,50.121445, 53.18814,50.122168, 53.1...
# 2  [53.259224,50.216663, 53.259209,50.216672, 53....
# 3  [53.213223,50.291229, 53.213392,50.291594, 53....
# 4  [53.213391,50.247921, 53.217799,50.24232, 53.2...

# %%
len(df_routes.number.unique())
# Out:
# 169

# %%
def parse_geom(x):
    points = [(float(i.split(',')[0]),float(i.split(',')[1])) for i in x]
    edges = [(points[i-1],points[i]) for i in range(1, len(points))]
    return edges
df_routes['geo'] = df_routes['geometry'].apply(parse_geom)

# %%
global_edges = set()
for i in df_routes['geo'].values:
    global_edges = global_edges | set(i)

# %%
len(global_edges)
# Out:
# 13309

# %%
df_routes.head()
# Out:
#   number               direction  type_id  performing  \
# 0      1  Железнодорожный вокзал        1        True
# 1      1          Красная Глинка        1        True
# 2     21               Юнгородок        1        True
# 3     21        Барбошина Поляна        1        True
# 4     27         кинотеатр "Луч"        1        True
#
#                                             geometry  \
# 0  [53.384692,50.169369, 53.384749,50.169603, 53....
# 1  [53.187111,50.121445, 53.18814,50.122168, 53.1...
# 2  [53.259224,50.216663, 53.259209,50.216672, 53....
# 3  [53.213223,50.291229, 53.213392,50.291594, 53....
# 4  [53.213391,50.247921, 53.217799,50.24232, 53.2...
#
#                                                  geo
# 0  [((53.384692, 50.169369), (53.384749, 50.16960...
# 1  [((53.187111, 50.121445), (53.18814, 50.122168...
# 2  [((53.259224, 50.216663), (53.259209, 50.21667...
# 3  [((53.213223, 50.291229), (53.213392, 50.29159...
# 4  [((53.213391, 50.247921), (53.217799, 50.24232...

# %%
req = requests.get('http://www.samaratrans.info/wiki/index.php/%D0%A1%D0%B0%D0%BC%D0%B0%D1%80%D0%B0_%D0%B0%D0%B2%D1%82%D0%BE%D0%B1%D1%83%D1%81_2')
html_text = req.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_text, 'html.parser')

# %%
collect_links = []
for j in soup.find_all('ul')[-6:]:
    for i in j.find_all('a'):
    try:
        if "маршруты" not in i['title'] and "расписания" not in i['title']:
        collect_links.append(i['href'])
    except KeyError:
        pass
len(collect_links)
# Out:
# 199

# %%
def parse_add_inf(t):
    additional_information = t.find_all('td')
    add_inf = {}
    for i in range(0,14,2):
        add_inf[additional_information[i].text.strip()] = additional_information[i+1].text.strip()
    return add_inf


def parse_route_page(soup):
    try:
        tables = soup.find_all('table')
        route_name = tables[2].find_all('li')[0].text.split('\n\n')[0]
        return route_name, parse_add_inf(tables[7])
    except:
        return None, None

# %%
DOMAIN_LINK = 'http://www.samaratrans.info'

parsed_routes = {}

# for link in collect_links:
#     r = requests.get(DOMAIN_LINK+link)
#     s = BeautifulSoup(r.text, 'html.parser')
#     name, inf = parse_route_page(s)
#     parsed_routes[name] = inf

# %%
# with open('file.txt', 'w') as f:
#     f.write(str(parsed_routes))
with open('file.txt', 'r') as f:

# %%
type_dict = {int(i.split(' — ')[0]): i.split(' — ')[1] for i in '''1 — автобус, 2 — метрополитен, 3 — трамвай, 4 — троллейбус, 5 — электропоезд, 6 — речной транспорт'''.split(', ')}
type_dict
# Out:
# {1: 'автобус',
#  2: 'метрополитен',
#  3: 'трамвай',
#  4: 'троллейбус',
#  5: 'электропоезд',
#  6: 'речной транспорт'}

# %%
routes_inf = []
exceptions = {}
for key, value in parsed_routes.items():
    try:
        key_splited = key.split(' ')
        number = key_splited[4]
        type_title = key_splited[1]
        schedule_days = { i.split(':')[0]: i.split(':')[1] 
                 for i in value['Режим работы'].split('По') if len(i.split(':')) > 1}
        intervals = value['Интервалы движения']
        vehicles = value['Подвижной состав']
        routes_inf.append([number, type_title, schedule_days, intervals, vehicles])
    except:
        print(key, value)
        exceptions[key] = value
# Out:
# 1 Автобусный маршрут № 7 "Безымянский рынок - ул. Транзитная (кольцевой)" {'отправление от Безымянского рынка': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# 1 Автобусный маршрут № 27 "Безымянский рынок - Кинотеатр "Луч" (кольцевой)" {'отправление от Безымянского рынка': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# 1 Автобусный маршрут № 59 "15-й микрорайон (ТЦ "Колизей") - Пост ГИБДД (кольцевой)" {'отправление от ТЦ "Колизей"': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# 1 Автобусный маршрут № 59а "15-й микрорайон (ТЦ "Колизей") - Пост ГИБДД (кольцевой)" {'отправление от ТЦ "Колизей"': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# None None
# 1 Автобусный маршрут № 126б "Завод "Металлург" - СДТ "Советы"" {'Дни работы': 'С 1 мая по 31 октября: по выходным и праздничным днямС 1 мая по 30 сентября: дополнительно по средам и пятницам(кроме дней массовых посещений кладбищ)', 'Время работы': 'С 7 до 10 часов и с 14 до 19 часов', 'Интервалы движения': '120 мин.', 'Выпуск на линию': '1 машина', 'Время в пути': '53 мин.', 'Протяжённость маршрута': '23,3 км', 'Обслуживающие предприятия': 'ООО "СамараАвтоГаз"'}
# 1 Автобусный маршрут № 132 "ул. Георгия Димитрова - ДМ "Сосновый Бор"" {'Дни работы': 'С 1 мая по 31 октября: по выходным и праздничным днямС 1 мая по 30 сентября: дополнительно по средам и пятницам(кроме дней массовых посещений кладбищ)', 'Время работы': 'С 7 до 10 часов и с 18 до 20 часов', 'Интервалы движения': '-', 'Выпуск на линию': '2 машины', 'Время в пути': 'От ул. Георгия Димитрова: 1 ч. 10 мин. - 1 ч. 30 мин.От а/ст "Красная Глинка": 40-50 мин.', 'Протяжённость маршрута': 'От ул. Георгия Димитрова: 47,2 кмОт а/ст "Красная Глинка": 28,2 км', 'Обслуживающие предприятия': 'ООО "СамараАвтоГаз"'}
# 1 Автобусный маршрут № 144 "Дом Печати - Сокские дачи" {'Дни работы': 'С 1 мая по 31 октября: по выходным и праздничным днямС 1 мая по 30 сентября: дополнительно по средам и пятницам(кроме дней массовых посещений кладбищ)', 'Время работы': 'С 7 до 12 часов и с 14 до 20 часов', 'Интервалы движения': 'По рабочим дням: 40-120 мин.По выходным дням: 26-52 мин.', 'Выпуск на линию': 'По рабочим дням: 2 машиныПо выходным дням: 3 машины', 'Время в пути': '1 ч. 10 мин. - 1 ч. 15 мин.', 'Протяжённость маршрута': 'До СНТ "Сокский-1": 26,7 кмДо Сокских дач: 37,6 км', 'Обслуживающие предприятия': 'ООО "СамараАвтоГаз"'}
# 1 Автобусный маршрут №
0 км', 'Обслуживающие предприятия': 'ООО "СамараАвтоГаз"'}
# 1 Автобусный маршрут № 77д "Хлебная площадь - Кладбище "Южное"" {'Дни работы': 'Пасха, Красная горка, Радоница, Троицкая родительская суббота, День Победы', 'Время работы': 'С 7 до 15 часов', 'Интервалы движения': '15-20 мин.', 'Выпуск на линию': '4-5 машин', 'Время в пути': '25-35 мин.', 'Протяжённость маршрута': '14,0 км', 'Обслуживающие предприятия': 'ООО "СамараАвтоГаз"'}
# 1 Автобусный маршрут № 129э "а/ст "Аврора" - Кладбище "Южное" (экспресс)" {'Дни работы': 'Пасха, Красная горка, Радоница, Троицкая родительская суббота, День Победы', 'Время работы': 'С 7 до 15 часов', 'Интервалы движения': '5-10 мин.', 'Выпуск на линию': 'До 20 машин', 'Время в пути': '20-25 мин.', 'Протяжённость маршрута': '19,2 км', 'Обслуживающие предприятия': 'ООО "СамараАвтоГаз"'}
# 1 Трамвайный маршрут № 4 "Постников овраг - Ж/д вокзал - Станция метро "Победа" - Постников овраг (кольцевой)" {'Остановки': 'Первые рейсы', 'Последние рейсы': 'рабочие', 'выходные': 'в обратном направлении до Постникова оврага', 'ул. Арцыбушевская': '5:08', '5:05': '-', '-': 'в прямом направлении по полному кругу'}
# 1 Трамвайный маршрут № 23 "Постников овраг - Станция метро "Победа" - Ж/д вокзал - Постников овраг (кольцевой)" {'Остановки': 'Первые рейсы', 'Последние рейсы': 'Примечание', 'рабочие': 'выходные', 'в прямом направлении по полному кругу': 'ул. Арцыбушевская', '5:21': '5:17', '-': '-'}

# %%
for key, value in exceptions.items():
    try:
        key_splited = key.split(' ')
        number = key_splited[4]
        type_title = key_splited[1]
        schedule_days = {value['Дни работы'] : value['Время работы'] }
        intervals = value['Интервалы движения']
        vehicles = value['Выпуск на линию']
        routes_inf.append([number, type_title, schedule_days, intervals, vehicles])
    except:
        print(key, value)
        exceptions[key] = value
# Out:
# 1 Автобусный маршрут № 7 "Безымянский рынок - ул. Транзитная (кольцевой)" {'отправление от Безымянского рынка': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# 1 Автобусный маршрут № 27 "Безымянский рынок - Кинотеатр "Луч" (кольцевой)" {'отправление от Безымянского рынка': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# 1 Автобусный маршрут № 59 "15-й микрорайон (ТЦ "Колизей") - Пост ГИБДД (кольцевой)" {'отправление от ТЦ "Колизей"': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# 1 Автобусный маршрут № 59а "15-й микрорайон (ТЦ "Колизей") - Пост ГИБДД (кольцевой)" {'отправление от ТЦ "Колизей"': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# None None
# 1 Автобусный маршрут № 157 "Площадь им. Кирова - Чёрновские дачи" {'отправление от площади им. Кирова': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# 1 Автобусный маршрут № 174 "а/ст "Аврора" - Аглосские дачи" {'отправление от автостанции "Аврора"': 'часы', '05': '06', '07': '08', '09': '10', '11': '12', '13': '14', '15': '16'}
# 1 Трамвайный маршрут № 4 "Постников овраг - Ж/д вокзал - Станция метро "Победа" - Постников овраг (кольцевой)" {'Остановки': 'Первые рейсы', 'Последние рейсы': 'рабочие', 'выходные': 'в обратном направлении до Постникова оврага', 'ул. Арцыбушевская': '5:08', '5:05': '-', '-': 'в прямом направлении по полному кругу'}
# 1 Трамвайный маршрут № 23 "Постников овраг - Станция метро "Победа" - Ж/д вокзал - Постников овраг (кольцевой)" {'Остановки': 'Первые рейсы', 'Последние рейсы': 'Примечание', 'рабочие': 'выходные', 'в прямом направлении по полному кругу': 'ул. Арцыбушевская', '5:21': '5:17', '-': '-'}

# %%
routes_inf.append(['7', 'Автобусный', {'Ежедневно': ' с 6 до 20 часов'}, 'По рабочим дням: 12-84 мин.По выходным дням: 68-164 мин.', 'ПАЗ-3203ПАЗ-3204ПАЗ-32054'])
routes_inf.append(['27', 'Автобусный', {'Ежедневно': ' с 6 до 20 часов'}, 'По рабочим дням: 12-44 мин.По субботам: 14-46 мин.По воскресеньям: 18-58 мин.', 'Hyundai County Kuzbas HDU2ПАЗ-3203ПАЗ-3204ПАЗ-32054'])
routes_inf.append(['59', 'Автобусный', {'Ежедневно': ' с 6 до 19 часов'}, '77 мин.', 'ПАЗ-3203'])
routes_inf.append(['59а', 'Автобусный', {'Ежедневно': ' с 6 до 19 часов'}, '77 мин.', 'ПАЗ-3203'])
routes_inf.append(['157', 'Автобусный', {'С 1 мая по 31 октября: по выходным и праздничным днямС 1 мая по 30 сентября: дополнительно по средам и пятницам(кроме дней массовых посещений кладбищ)': 'С 7 до 12 часов и с 15 до 20 часов'}, 'По рабочим дням: 30-35 мин.По выходным дням: 25-50 мин.', 'ЛиАЗ-5293.70МАЗ-206'])
routes_inf.append(['174', 'Автобусный', {'С 1 мая по 31 октября: по выходным и праздничным днямС 1 мая по 30 сентября: дополнительно по средам и пятницам(кроме дней массовых посещений кладбищ)': 'С 7 до 12 часов и с 16 до 19 часов'}, '45-50 мин.', 'МАЗ-206'])
routes_inf.append(['4', 'Трамвайный', {'Ежедневно': 'с 5 до 21 часа'}, '14 мин.', 'Tatra T3SU (Т-3) (одиночные вагоны)АКСМ-62103 (одиночные вагоны)'])
routes_inf.append(['4', 'Трамвайный', {' рабочим дням': ' с 6 до 23 часов', ' выходным дням': ' с 6 до 22 часов'}, 'По рабочим дням: 16 мин.По выходным дням: 14 мин.', 'Tatra T3SU (Т-3) (одиночные вагоны)АКСМ-62103 (одиночные вагоны)71-402 "СПЕКТР" (одиночные вагоны)'])

# %%
df_routes_inf = pd.DataFrame(routes_inf, columns=['number', 'type_title', 'schedule_days', 'intervals', 'vehicles'])
df_routes_inf
# Out:
#     number  type_title                                      schedule_days  \
# 0        1  Автобусный                  {'Ежедневно': ' с 6 до 22 часов'}
# 1        3  Автобусный                  {'Ежедневно': ' с 7 до 20 часов'}
# 2        4  Автобусный                   {'Ежедневно': ' с 6 до 21 часа'}
# 3       5д  Автобусный                  {'Ежедневно': ' с 5 до 22 часов'}
# 4        6  Автобусный                   {'Ежедневно': ' с 6 до 21 часа'}
# ..     ...         ...                                                ...
# 182    59а  Автобусный                  {'Ежедневно': ' с 6 до 19 часов'}
# 183    157  Автобусный  {'С 1 мая по 31 октября: по выходным и праздни...
# 184    174  Автобусный  {'С 1 мая по 31 октября: по выходным и праздни...
# 185      4  Трамвайный                    {'Ежедневно': 'с 5 до 21 часа'}
# 186      4  Трамвайный  {' рабочим дням': ' с 6 до 23 часов', ' выходн...
#
#                                              intervals  \
# 0    По рабочим дням: 8-20 мин.По выходным дням: 16...
# 1                                           48-60 мин.
# 2                                            7-10 мин.
# 3    По рабочим дням: 10-20 мин.По выходным дням: 1...
# 4    По рабочим дням: 15-34 мин.По выходным дням: 1...
# ..                                                 ...
# 182                                            77 мин.
# 183  По рабочим дням: 30-35 мин.По выходным дням: 2...
# 184                                         45-50 мин.
# 185                                            14 мин.
# 186  По рабочим дням: 16 мин.По выходным дням: 14 мин.
#
#                                               vehicles
# 0                                         ЛиАЗ-5293.70
# 1                                              МАЗ-206
# 2                               Автобусы малого класса
# 3                                         ЛиАЗ-5293.70
# 4                                              МАЗ-206
# ..                                                 ...
# 182                                           ПАЗ-3203
# 183                                ЛиАЗ-5293.70МАЗ-206
# 184                                            МАЗ-206
# 185  Tatra T3SU (Т-3) (одиночные вагоны)АКСМ-62103 ...
# 186  Tatra T3SU (Т-3) (одиночные вагоны)АКСМ-62103 ...
#
# [187 rows x 5 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-cce0092130c5> in <module>
# ----> 1 df_routes_inf.describe()
#
# D:\anaconda\envs\samaraOT\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#   10276             data = self.select_dtypes(include=include, exclude=exclude)
#   10277
# > 10278         ldesc = [describe_1d(s) for _, s in data.items()]
#   10279         # set a convenient order for rows
#   10280         names = []
#
# D:\anaconda\envs\samaraOT\lib\site-packages\pandas\core\generic.py in <listcomp>(.0)
#   10276             data = self.select_dtypes(include=include, exclude=exclude)
#   10277
# > 10278         ldesc = [describe_1d(s) for _, s in data.items()]
#   10279         # set a convenient order for rows
#   10280         names = []
#
# D:\anaconda\envs\samaraOT\lib\site-packages\pandas\core\generic.py in describe_1d(data)
#   10259                 return describe_numeric_1d(data)
#   10260             else:
# > 10261                 return describe_categorical_1d(data)
#   10262
#   10263         if self.ndim == 1:
#
# D:\anaconda\envs\samaraOT\lib\site-packages\pandas\core\generic.py in describe_categorical_1d(data)
#   10215         def describe_categorical_1d(data):
#   10216             names = ["count", "unique"]
# > 10217             objcounts = data.value_counts()
#   10218             count_unique = len(objcounts[objcounts != 0])
#   10219             result = [data.count(), count_unique]
#
# D:\anaconda\envs\samaraOT\lib\site-packages\pandas\core\base.py in value_counts(self, normalize, sort, ascending, bins, dropna)
#    1390             normalize=normalize,
#    1391             bins=bins,
# -> 1392             dropna=dropna,
#    1393         )
#    1394         return result
#
# D:\anaconda\envs\samaraOT\lib\site-packages\pandas\core\algorithms.py in value_counts(values, sort, ascending, normalize, bins, dropna)
#     755
#     756         else:
# --> 757             keys, counts = _value_counts_arraylike(values, dropna)
#     758
#     759             if not isinstance(keys, Index):
#
# D:\anaconda\envs\samaraOT\lib\site-packages\pandas\core\algorithms.py in _value_counts_arraylike(values, dropna)
#     800         # TODO: handle uint8
#     801         f = getattr(htable, "value_count_{dtype}".format(dtype=ndtype))
# --> 802         keys, counts = f(values, dropna)
#     803
#     804         mask = isna(values)
#
# pandas\_libs\hashtable_func_helper.pxi in pandas._libs.hashtable.value_count_object()
#
# pandas\_libs\hashtable_func_helper.pxi in pandas._libs.hashtable.value_count_object()
#
# TypeError: unhashable type: 'dict'
